# %% [markdown]
# ## **GRU**

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,GRU,Dense
from tensorflow.keras.preprocessing import sequence

# %%
max_words = 6000
(xt,yt),(xte,yte)= imdb.load_data(num_words=max_words)

max_len =500
xt=sequence.pad_sequences(xt,maxlen=max_len)
xte=sequence.pad_sequences(xte,maxlen=max_len)

model=Sequential()
model.add(Embedding(max_words,100,input_length=max_len))
model.add(GRU(128))
model.add(Dense(1,activation='sigmoid'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
batch_size=128
epochs=10
model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 50s 217ms/step - loss: 0.5249 - accuracy: 0.7318
# Epoch 2/10
# 196/196 [==============================] - 26s 135ms/step - loss: 0.3003 - accuracy: 0.8756
# Epoch 3/10
# 196/196 [==============================] - 22s 111ms/step - loss: 0.2378 - accuracy: 0.9065
# Epoch 4/10
# 196/196 [==============================] - 13s 68ms/step - loss: 0.1997 - accuracy: 0.9241
# Epoch 5/10
# 196/196 [==============================] - 12s 63ms/step - loss: 0.1604 - accuracy: 0.9408
# Epoch 6/10
# 196/196 [==============================] - 11s 55ms/step - loss: 0.1367 - accuracy: 0.9509
# Epoch 7/10
# 196/196 [==============================] - 7s 37ms/step - loss: 0.1053 - accuracy: 0.9635
# Epoch 8/10
# 196/196 [==============================] - 9s 48ms/step - loss: 0.0865 - accuracy: 0.9700
# Epoch 9/10
# 196/196 [==============================] - 8s 41ms/step - loss: 0.0663 - accuracy: 0.9784
# Epoch 10/10
# 196/196 [==============================] - 7s 36ms/step - loss: 0.0550 - accuracy: 0.9827

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 12ms/step - loss: 0.5176 - accuracy: 0.8578
# accuracy: 0.8578400015830994
# loss: 0.5175539255142212

# %%
history=model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 8s 43ms/step - loss: 0.0554 - accuracy: 0.9823
# Epoch 2/10
# 196/196 [==============================] - 9s 44ms/step - loss: 0.0554 - accuracy: 0.9812
# Epoch 3/10
# 196/196 [==============================] - 8s 39ms/step - loss: 0.0247 - accuracy: 0.9932
# Epoch 4/10
# 196/196 [==============================] - 7s 38ms/step - loss: 0.0226 - accuracy: 0.9932
# Epoch 5/10
# 196/196 [==============================] - 7s 35ms/step - loss: 0.0297 - accuracy: 0.9907
# Epoch 6/10
# 196/196 [==============================] - 8s 39ms/step - loss: 0.0378 - accuracy: 0.9870
# Epoch 7/10
# 196/196 [==============================] - 7s 36ms/step - loss: 0.0165 - accuracy: 0.9959
# Epoch 8/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.0199 - accuracy: 0.9938
# Epoch 9/10
# 196/196 [==============================] - 7s 35ms/step - loss: 0.0115 - accuracy: 0.9967
# Epoch 10/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.0083 - accuracy: 0.9982

# %%
train_loss1 = history.history['loss']
train_acc1 = history.history['accuracy']
xc1=range(len(train_acc1))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc1, train_acc1)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# ## **LSTM**

# %%
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(LSTM(128))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 5
batch_size = 128

hist=model.fit(xt, yt, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 37s 171ms/step - loss: 0.4537 - accuracy: 0.7854
# Epoch 2/5
# 196/196 [==============================] - 21s 106ms/step - loss: 0.2647 - accuracy: 0.8936
# Epoch 3/5
# 196/196 [==============================] - 14s 74ms/step - loss: 0.2316 - accuracy: 0.9104
# Epoch 4/5
# 196/196 [==============================] - 13s 65ms/step - loss: 0.1806 - accuracy: 0.9337
# Epoch 5/5
# 196/196 [==============================] - 12s 60ms/step - loss: 0.1480 - accuracy: 0.9455

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 4s 14ms/step - loss: 0.3562 - accuracy: 0.8692
# accuracy: 0.8691999912261963
# loss: 0.35619890689849854

# %%
train_loss2 = hist.history['loss']
train_acc2 = hist.history['accuracy']
xc2=range(len(train_acc2))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc2, train_acc2)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# ## **RNN**

# %%
from tensorflow.keras.layers import Embedding,RNN
from keras import layers

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(layers.LSTM(128))
model.add(layers.Dense(10))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 7
batch_size = 128

h=model.fit(xt, yt, epochs=epochs, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/7
# 157/157 [==============================] - 30s 171ms/step - loss: 0.4985 - accuracy: 0.7503 - val_loss: 0.3245 - val_accuracy: 0.8658
# Epoch 2/7
# 157/157 [==============================] - 16s 103ms/step - loss: 0.2713 - accuracy: 0.8893 - val_loss: 0.3003 - val_accuracy: 0.8738
# Epoch 3/7
# 157/157 [==============================] - 15s 93ms/step - loss: 0.2114 - accuracy: 0.9179 - val_loss: 0.3544 - val_accuracy: 0.8608
# Epoch 4/7
# 157/157 [==============================] - 13s 83ms/step - loss: 0.1653 - accuracy: 0.9384 - val_loss: 0.3588 - val_accuracy: 0.8684
# Epoch 5/7
# 157/157 [==============================] - 10s 65ms/step - loss: 0.1400 - accuracy: 0.9477 - val_loss: 0.4532 - val_accuracy: 0.8720
# Epoch 6/7
# 157/157 [==============================] - 9s 58ms/step - loss: 0.0990 - accuracy: 0.9658 - val_loss: 0.4758 - val_accuracy: 0.8458
# Epoch 7/7
# 157/157 [==============================] - 10s 62ms/step - loss: 0.0738 - accuracy: 0.9759 - val_loss: 0.5499 - val_accuracy: 0.8576

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 15ms/step - loss: 0.5489 - accuracy: 0.8506
# accuracy: 0.8506399989128113
# loss: 0.5488559603691101

# %%
train_loss3 = h.history['loss']
train_acc3 = h.history['accuracy']
xc3=range(len(train_loss3))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %%
plt.plot(xc1, train_acc1)
plt.plot(xc2, train_acc2)
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["GRU","LSTM","RNN"])
